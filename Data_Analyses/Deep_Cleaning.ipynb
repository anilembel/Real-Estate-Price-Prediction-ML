# %% [markdown]
# ## <p style="background-color:#16A085; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Step 1 : Small Look and understanding data </p>

# %%
import numpy as np
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt
from skimpy import clean_columns

import warnings
warnings.filterwarnings("ignore")
warnings.warn("this will not show")

# %matplotlib inline
# %matplotlib notebook

plt.rcParams["figure.figsize"] = (10,6)
# plt.rcParams['figure.dpi'] = 100

sns.set_style("whitegrid")
pd.set_option('display.float_format', lambda x: '%.2f' % x)

pd.options.display.max_rows = 100
pd.options.display.max_columns = 100

# %%
df1 = pd.read_csv("immo_data.csv")
df1
# Out:
#                   locality   Price       Type_property Sale_type  \
# 0       libramont-chevigny  145500           apartment  for-sale
# 1      la-roche-en-ardenne  185000  mixed-use-building  for-sale
# 2                   manhay  228000           apartment  for-sale
# 3                  bertrix  249500               house  for-sale
# 4             saint-hubert  295000               house  for-sale
# ...                    ...     ...                 ...       ...
# 59845              leisele  360000     country-cottage  for-sale
# 59846              de-haan  375000               house  for-sale
# 59847             oostende  410000               house  for-sale
# 59848          middelkerke  410000               villa  for-sale
# 59849                menen  449000               villa  for-sale
#
#       Number_bedrooms Living_area fully_equipped_kitchen Furnished terrace  \
# 0                   1          40                      1         0       8
# ...

# %%
df = pd.read_csv("data_a.csv")
df
# Out:
#        Unnamed: 0 To rent To sell     Price  Number of rooms  Living Area  \
# 0         1610665    True   False    485.00             1.00        40.00
# 1         2718948    True   False    790.00             2.00       140.00
# 2         3229637    True   False    900.00             3.00       103.00
# 3         3860205    True   False    520.00             2.00        50.00
# 4         4141598    True   False    760.00             1.00        55.00
# ...           ...     ...     ...       ...              ...          ...
# 78187    10316113   False    True 349000.00             4.00          NaN
# 78188    10316130    True   False    590.00             1.00          NaN
# 78189    10316135    True   False    595.00             1.00          NaN
# 78190    10316134    True   False   1150.00             3.00       800.00
# 78191    10316136    True   False   1590.00             3.00       100.00
#
#       Fully equipped kitchen Furnished  Open fire  Terrace  \
# ...

# %% [markdown]
# #### Customizing the Names of the columns

# %%
df_c = df.copy()

# %%
from skimpy import clean_columns

df = clean_columns(df)
df
# Out:
# 18 column names have been cleaned
#        unnamed_0 to_rent to_sell     price  number_of_rooms  living_area  \
# 0        1610665    True   False    485.00             1.00        40.00
# 1        2718948    True   False    790.00             2.00       140.00
# 2        3229637    True   False    900.00             3.00       103.00
# 3        3860205    True   False    520.00             2.00        50.00
# 4        4141598    True   False    760.00             1.00        55.00
# ...          ...     ...     ...       ...              ...          ...
# 78187   10316113   False    True 349000.00             4.00          NaN
# 78188   10316130    True   False    590.00             1.00          NaN
# 78189   10316135    True   False    595.00             1.00          NaN
# 78190   10316134    True   False   1150.00             3.00       800.00
# 78191   10316136    True   False   1590.00             3.00       100.00
#
# ...

# %%
df.rename(columns={"unnamed_0": "index_link",}, inplace=True)

df.head(3)
# Out:
#    index_link to_rent to_sell  price  number_of_rooms  living_area  \
# 0     1610665    True   False 485.00             1.00        40.00
# 1     2718948    True   False 790.00             2.00       140.00
# 2     3229637    True   False 900.00             3.00       103.00
#
#   fully_equipped_kitchen furnished  open_fire  terrace  area_of_the_terrace  \
# 0                   True     False      False    False                 0.00
# 1                   True     False      False    False                 0.00
# 2                    NaN     False      False    False                 0.00
#
#    garden  area_of_the_garden  surface_of_the_land  \
# 0   False                0.00                  NaN
# 1   False                0.00                  NaN
# 2    True              330.00               400.00
#
#    surface_area_of_the_plot_of_land  number_of_facades  swimming_pool  \
# 0                               NaN               2.00          False
# ...

# %%
df.sample(10)
# Out:
#        index_link to_rent to_sell     price  number_of_rooms  living_area  \
# 66427    10269543   False    True 392865.00             3.00       195.00
# 10225    10211788    True   False   2400.00             3.00       180.00
# 7693     10296532    True   False    450.00              NaN        28.00
# 12336    10289710    True   False   1300.00             2.00       125.00
# 72959    10131790     NaN     NaN       NaN              NaN          NaN
# 56085    10309685   False    True 725000.00             3.00       250.00
# 295       9766375    True   False   1590.00             1.00          NaN
# 25467    10161769   False    True 189000.00             3.00        90.00
# 62139    10247842    True   False    480.00              NaN        27.00
# 62987    10237298    True   False   1500.00             4.00          NaN
#
#       fully_equipped_kitchen furnished  open_fire  terrace  \
# 66427                    NaN     False      False    False
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 78192 entries, 0 to 78191
# Data columns (total 20 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   index_link                        78192 non-null  int64
#  1   to_rent                           74200 non-null  object
#  2   to_sell                           74200 non-null  object
#  3   price                             74200 non-null  float64
#  4   number_of_rooms                   73277 non-null  float64
#  5   living_area                       62305 non-null  float64
#  6   fully_equipped_kitchen            47940 non-null  object
#  7   furnished                         51057 non-null  object
#  8   open_fire                         78192 non-null  bool
#  9   terrace                           78192 non-null  bool
#  10  area_of_the_terrace               61406 non-null  float64
# ...

# %%
df.shape
# Out:
# (78192, 20)

# %% [markdown]
# #### The Percantage of the Nan Values of the columns

# %%
df.isnull().sum()
# Out:
# index_link                              0
# to_rent                              3992
# to_sell                              3992
# price                                3992
# number_of_rooms                      4915
# living_area                         15887
# fully_equipped_kitchen              30252
# furnished                           27135
# open_fire                               0
# terrace                                 0
# area_of_the_terrace                 16786
# garden                                  0
# area_of_the_garden                   8579
# surface_of_the_land                 43849
# surface_area_of_the_plot_of_land    43849
# number_of_facades                   24991
# swimming_pool                           0
# state_of_the_building               25132
# zipcode                                 0
# type                                    1
# dtype: int64

# %%
df.isnull().sum()*100 / df.shape[0]
# Out:
# index_link                          0.00
# to_rent                             5.11
# to_sell                             5.11
# price                               5.11
# number_of_rooms                     6.29
# living_area                        20.32
# fully_equipped_kitchen             38.69
# furnished                          34.70
# open_fire                           0.00
# terrace                             0.00
# area_of_the_terrace                21.47
# garden                              0.00
# area_of_the_garden                 10.97
# surface_of_the_land                56.08
# surface_area_of_the_plot_of_land   56.08
# number_of_facades                  31.96
# swimming_pool                       0.00
# state_of_the_building              32.14
# zipcode                             0.00
# type                                0.00
# dtype: float64

# %% [markdown]
# ## <p style="background-color:#16A085; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Step 2 : Researches about All Columns </p>

# %% [markdown]
# #### <p style="background-color:#F39C12; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">index_link </p>

# %%
df
# Out:
#        index_link to_rent to_sell     price  number_of_rooms  living_area  \
# 0         1610665    True   False    485.00             1.00        40.00
# 1         2718948    True   False    790.00             2.00       140.00
# 2         3229637    True   False    900.00             3.00       103.00
# 3         3860205    True   False    520.00             2.00        50.00
# 4         4141598    True   False    760.00             1.00        55.00
# ...           ...     ...     ...       ...              ...          ...
# 78187    10316113   False    True 349000.00             4.00          NaN
# 78188    10316130    True   False    590.00             1.00          NaN
# 78189    10316135    True   False    595.00             1.00          NaN
# 78190    10316134    True   False   1150.00             3.00       800.00
# 78191    10316136    True   False   1590.00             3.00       100.00
#
#       fully_equipped_kitchen furnished  open_fire  terrace  \
# ...

# %%
df.index_link.value_counts(dropna=False)
# Out:
# 1610665     1
# 10270141    1
# 10270206    1
# 10270203    1
# 10270197    1
#            ..
# 10169704    1
# 10169690    1
# 10169682    1
# 10169681    1
# 10316136    1
# Name: index_link, Length: 78192, dtype: int64

# %%
# A data analyst should primarily benefit from all incoming data s/he encounters; HOWEVER,
# Even if url contains some information, we do NOT need it since this information can be obtained from other features.

df.drop("index_link", axis=1, inplace=True)

# %% [markdown]
# #### <p style="background-color:#F39C12; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;"> to_rent </p>

# %%
df.to_rent.value_counts(dropna=False)
# Out:
# False    57005
# True     17195
# NaN       3992
# Name: to_rent, dtype: int64

# %% [markdown]
# #### <p style="background-color:#F39C12; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;"> to_sell </p>

# %%
df.to_sell.value_counts(dropna=False)
# Out:
# True     57005
# False    17195
# NaN       3992
# Name: to_sell, dtype: int64

# %%
# it can be removed as both for rent and for sale are opposite to each other as True False 
# so our data is easier to understand and extra columns are avoided

# %%
df.drop("to_sell", axis=1, inplace=True)

# %%
df.columns
# Out:
# Index(['to_rent', 'price', 'number_of_rooms', 'living_area',
#        'fully_equipped_kitchen', 'furnished', 'open_fire', 'terrace',
#        'area_of_the_terrace', 'garden', 'area_of_the_garden',
#        'surface_of_the_land', 'surface_area_of_the_plot_of_land',
#        'number_of_facades', 'swimming_pool', 'state_of_the_building',
#        'zipcode', 'type'],
#       dtype='object')

# %%
df.shape
# Out:
# (78192, 18)

# %% [markdown]
# #### <p style="background-color:#F39C12; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;"> price </p>

# %%
df.price.value_counts(dropna=False)
# Out:
# NaN          3992
# 299000.00     940
# 249000.00     923
# 199000.00     805
# 750.00        780
#              ...
# 273250.00       1
# 261750.00       1
# 899900.00       1
# 119750.00       1
# 249990.00       1
# Name: price, Length: 5443, dtype: int64

# %%
# There are 3992 unpriced data, which makes it 5.11%
# I'm dropping these prices because un-entered data won't be of use to us. 
# I could not fill with mean or median variables with price

# %%
df.sample(3)
# Out:
#       to_rent     price  number_of_rooms  living_area fully_equipped_kitchen  \
# 67263   False 421000.00             2.00       122.00                    NaN
# 75376   False 370000.00             3.00       157.00                    NaN
# 42791   False 295000.00             3.00          NaN                   True
#
#       furnished  open_fire  terrace  area_of_the_terrace  garden  \
# 67263     False      False     True                12.00    True
# 75376     False      False     True                30.00   False
# 42791       NaN      False    False                 0.00   False
#
#        area_of_the_garden  surface_of_the_land  \
# 67263                 NaN                  NaN
# 75376                0.00               412.00
# 42791                0.00                  NaN
#
#        surface_area_of_the_plot_of_land  number_of_facades  swimming_pool  \
# 67263                               NaN                NaN          False
# ...

# %%
df = df.dropna(subset=['price'])
df.price.value_counts(dropna=False)
# Out:
# 299000.00    940
# 249000.00    923
# 199000.00    805
# 750.00       780
# 850.00       733
#             ...
# 284059.00      1
# 277987.00      1
# 248170.00      1
# 318847.00      1
# 249990.00      1
# Name: price, Length: 5442, dtype: int64

# %%
df.price.isnull().sum()
# Out:
# 0

# %%
df.shape
# Out:
# (74200, 18)

# %% [markdown]
# #### <p style="background-color:#F39C12; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;"> number_of_rooms </p>

# %%
df.number_of_rooms.value_counts(dropna=False)
# Out:
# 2.00       24486
# 3.00       22582
# 4.00        9703
# 1.00        9092
# 5.00        3630
# NaN         1918
# 6.00        1402
# 7.00         507
# 8.00         301
# 9.00         136
# 10.00        135
# 12.00         65
# 11.00         48
# 15.00         33
# 14.00         30
# 13.00         27
# 16.00         17
# 18.00         15
# 20.00         12
# 17.00         11
# 30.00          7
# 37.00          5
# 24.00          4
# 28.00          3
# 25.00          3
# 70.00          2
# 27.00          2
# 19.00          2
# 21.00          2
# 32.00          2
# 26.00          2
# 48.00          2
# 100.00         1
# 123.00         1
# 2020.00        1
# 22.00          1
# 50.00          1
# 36.00          1
# 33.00          1
# 90.00          1
# 45.00          1
# 38.00          1
# 23.00          1
# 79.00          1
# 35.00          1
# 31.00          1
# Name: number_of_rooms, dtype: int64

# %%
# I' m dropping all the houses which have more than 10 rooms

df = df[df["number_of_rooms"] <= 10]
df.sample(3)
# Out:
#       to_rent     price  number_of_rooms  living_area fully_equipped_kitchen  \
# 44184   False 295464.00             2.00          NaN                   True
# 19017   False 620000.00             4.00       307.00                    NaN
# 35560   False 430000.00             4.00       140.00                   True
#
#       furnished  open_fire  terrace  area_of_the_terrace  garden  \
# 44184       NaN      False     True                54.00   False
# 19017     False      False    False                 0.00    True
# 35560     False      False     True                10.00   False
#
#        area_of_the_garden  surface_of_the_land  \
# 44184                0.00                  NaN
# 19017                 NaN               800.00
# 35560                0.00                70.00
#
#        surface_area_of_the_plot_of_land  number_of_facades  swimming_pool  \
# 44184                               NaN                NaN          False
# ...

# %%
df.shape
# Out:
# (71974, 18)

# %%
df.number_of_rooms.value_counts(dropna=False)
# Out:
# 2.00     24486
# 3.00     22582
# 4.00      9703
# 1.00      9092
# 5.00      3630
# 6.00      1402
# 7.00       507
# 8.00       301
# 9.00       136
# 10.00      135
# Name: number_of_rooms, dtype: int64

# %%
df.number_of_rooms.value_counts(dropna=False)
# Out:
# 2.00     24486
# 3.00     22582
# 4.00      9703
# 1.00      9092
# 5.00      3630
# 6.00      1402
# 7.00       507
# 8.00       301
# 9.00       136
# 10.00      135
# Name: number_of_rooms, dtype: int64

# %% [markdown]
# #### <p style="background-color:#F39C12; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;"> living area </p>

# %%
df.living_area.value_counts(dropna=False)
# Out:
# NaN         11586
# 100.00       1340
# 90.00        1299
# 120.00       1109
# 80.00        1072
#             ...
# 1193.00         1
# 11000.00        1
# 1367.00         1
# 1126.00         1
# 1246.00         1
# Name: living_area, Length: 824, dtype: int64

# %%
df['living_area'].isnull().sum()
# Out:
# 11586

# %%
df.living_area.describe()
# Out:
# count   60388.00
# mean      160.51
# std       213.12
# min         1.00
# 25%        90.00
# 50%       128.00
# 75%       187.00
# max     25325.00
# Name: living_area, dtype: float64

# %%
df['living_area']
# Out:
# 0        40.00
# 1       140.00
# 2       103.00
# 3        50.00
# 4        55.00
#          ...
# 78187      NaN
# 78188      NaN
# 78189      NaN
# 78190   800.00
# 78191   100.00
# Name: living_area, Length: 71974, dtype: float64

# %%
df['living_area'].mean()
# Out:
# 160.50541498310923

# %%
def fill_with_mean(df):
    mean_living = df['living_area'].mean()
    df['living_area'].fillna(mean_living, inplace=True)
    return df

# %%
fill_with_mean(df)
# Out:
#       to_rent     price  number_of_rooms  living_area fully_equipped_kitchen  \
# 0        True    485.00             1.00        40.00                   True
# 1        True    790.00             2.00       140.00                   True
# 2        True    900.00             3.00       103.00                    NaN
# 3        True    520.00             2.00        50.00                   True
# 4        True    760.00             1.00        55.00                   True
# ...       ...       ...              ...          ...                    ...
# 78187   False 349000.00             4.00       160.51                    NaN
# 78188    True    590.00             1.00       160.51                   True
# 78189    True    595.00             1.00       160.51                    NaN
# 78190    True   1150.00             3.00       800.00                   True
# 78191    True   1590.00             3.00       100.00                   True
#
# ...

# %%
df.living_area.value_counts(dropna=False)
# Out:
# 160.51      11586
# 100.00       1340
# 90.00        1299
# 120.00       1109
# 80.00        1072
#             ...
# 1193.00         1
# 11000.00        1
# 1367.00         1
# 1126.00         1
# 1246.00         1
# Name: living_area, Length: 824, dtype: int64

# %%
df['living_area'].isnull().sum()
# Out:
# 0

# %%
df.shape
# Out:
# (71974, 18)

# %%
df['living_area'].describe()
# Out:
# count   71974.00
# mean      160.51
# std       195.21
# min         1.00
# 25%        97.00
# 50%       149.00
# 75%       173.00
# max     25325.00
# Name: living_area, dtype: float64

# %%
df['living_area'].value_counts(dropna=False)
# Out:
# 160.51      11586
# 100.00       1340
# 90.00        1299
# 120.00       1109
# 80.00        1072
#             ...
# 1193.00         1
# 11000.00        1
# 1367.00         1
# 1126.00         1
# 1246.00         1
# Name: living_area, Length: 824, dtype: int64

# %%
df= df[(df['living_area']<=200) & (df['living_area']>= 20)]

# %%
df['living_area'].value_counts(dropna=False)
# Out:
# 160.51    11586
# 100.00     1340
# 90.00      1299
# 120.00     1109
# 80.00      1072
#           ...
# 26.00         9
# 31.00         9
# 21.00         7
# 24.00         6
# 22.00         4
# Name: living_area, Length: 182, dtype: int64

# %%
df['living_area'].describe()
# Out:
# count   59443.00
# mean      124.97
# std        40.41
# min        20.00
# 25%        90.00
# 50%       127.00
# 75%       160.51
# max       200.00
# Name: living_area, dtype: float64

# %%
df.columns
# Out:
# Index(['to_rent', 'price', 'number_of_rooms', 'living_area',
#        'fully_equipped_kitchen', 'furnished', 'open_fire', 'terrace',
#        'area_of_the_terrace', 'garden', 'area_of_the_garden',
#        'surface_of_the_land', 'surface_area_of_the_plot_of_land',
#        'number_of_facades', 'swimming_pool', 'state_of_the_building',
#        'zipcode', 'type'],
#       dtype='object')

# %% [markdown]
# #### <p style="background-color:#F39C12; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">  fully_equipped_kitchen </p>

# %%
df.fully_equipped_kitchen.value_counts(dropna=False)
# Out:
# True     36010
# NaN      21444
# False     1989
# Name: fully_equipped_kitchen, dtype: int64

# %%
df = df.dropna(subset=['fully_equipped_kitchen'])
df.fully_equipped_kitchen.value_counts(dropna=False)
# Out:
# True     36010
# False     1989
# Name: fully_equipped_kitchen, dtype: int64

# %%
df.fully_equipped_kitchen.value_counts(dropna=False)
# Out:
# True     36010
# False     1989
# Name: fully_equipped_kitchen, dtype: int64

# %%
df.shape
# Out:
# (37999, 18)

# %%
df.columns
# Out:
# Index(['to_rent', 'price', 'number_of_rooms', 'living_area',
#        'fully_equipped_kitchen', 'furnished', 'open_fire', 'terrace',
#        'area_of_the_terrace', 'garden', 'area_of_the_garden',
#        'surface_of_the_land', 'surface_area_of_the_plot_of_land',
#        'number_of_facades', 'swimming_pool', 'state_of_the_building',
#        'zipcode', 'type'],
#       dtype='object')

# %%
df.drop(["surface_of_the_land","surface_area_of_the_plot_of_land","number_of_facades"],axis=1,inplace=True)

# %%
df.sample(5)
# Out:
#       to_rent     price  number_of_rooms  living_area fully_equipped_kitchen  \
# 21184   False 349000.00             2.00       112.00                   True
# 46348   False 167500.00             3.00        80.00                   True
# 26230   False 135000.00             2.00       114.00                   True
# 68104   False 565000.00             2.00        81.00                   True
# 48519   False 299500.00             2.00        98.00                   True
#
#       furnished  open_fire  terrace  area_of_the_terrace  garden  \
# 21184     False      False     True                14.00   False
# 46348     False      False     True                  NaN   False
# 26230     False      False     True                35.00    True
# 68104     False      False     True                58.00   False
# 48519     False      False     True                 8.00   False
#
#        area_of_the_garden  swimming_pool state_of_the_building  zipcode  \
# ...

# %%
df.describe()
# Out:
#           price  number_of_rooms  living_area  area_of_the_terrace  \
# count  37999.00         37999.00     37999.00             30342.00
# mean  214200.42             2.44       122.49                11.92
# std   184123.57             0.99        40.67                38.52
# min       45.00             1.00        20.00                 0.00
# 25%     1322.50             2.00        89.00                 0.00
# 50%   220000.00             2.00       120.00                 5.00
# 75%   326190.00             3.00       160.51                16.00
# max   999999.00            10.00       200.00              3534.00
#
#        area_of_the_garden  zipcode
# count            34355.00 37999.00
# mean                99.49  5026.32
# std               1726.72  2928.96
# min                  0.00   236.00
# 25%                  0.00  2270.00
# 50%                  0.00  4500.00
# 75%                  0.00  8200.00
# max             240000.00  9992.00

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 37999 entries, 0 to 78191
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   to_rent                 37999 non-null  object
#  1   price                   37999 non-null  float64
#  2   number_of_rooms         37999 non-null  float64
#  3   living_area             37999 non-null  float64
#  4   fully_equipped_kitchen  37999 non-null  object
#  5   furnished               28220 non-null  object
#  6   open_fire               37999 non-null  bool
#  7   terrace                 37999 non-null  bool
#  8   area_of_the_terrace     30342 non-null  float64
#  9   garden                  37999 non-null  bool
#  10  area_of_the_garden      34355 non-null  float64
#  11  swimming_pool           37999 non-null  bool
#  12  state_of_the_building   29429 non-null  object
#  13  zipcode                 37999 non-null  int64
# ...

# %% [markdown]
# #### <p style="background-color:#F39C12; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">  furnished </p>

# %%
df.furnished.value_counts(dropna=False)
# Out:
# False    26587
# NaN       9779
# True      1633
# Name: furnished, dtype: int64

# %%
df = df.dropna(subset=['furnished'])
df.furnished.value_counts(dropna=False)
# Out:
# False    26587
# True      1633
# Name: furnished, dtype: int64

# %%
df.shape
# Out:
# (28220, 15)

# %%
df.isnull().sum()
# Out:
# to_rent                      0
# price                        0
# number_of_rooms              0
# living_area                  0
# fully_equipped_kitchen       0
# furnished                    0
# open_fire                    0
# terrace                      0
# area_of_the_terrace       5676
# garden                       0
# area_of_the_garden        3026
# swimming_pool                0
# state_of_the_building     6321
# zipcode                      0
# type                         0
# dtype: int64

# %% [markdown]
# #### <p style="background-color:#F39C12; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;"> open_fire </p>

# %%
df.open_fire.value_counts(dropna=False)
# Out:
# False    27419
# True       801
# Name: open_fire, dtype: int64

# %% [markdown]
# #### <p style="background-color:#F39C12; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">  terrace </p>

# %%
df.terrace.value_counts(dropna=False)
# Out:
# True     18317
# False     9903
# Name: terrace, dtype: int64

# %% [markdown]
# #### <p style="background-color:#F39C12; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">  area_of_the_terrace </p>

# %%
df.area_of_the_terrace.value_counts(dropna=False)
# Out:
# 0.00      9903
# NaN       5676
# 10.00      918
# 20.00      784
# 6.00       683
#           ...
# 136.00       1
# 185.00       1
# 187.00       1
# 126.00       1
# 98.00        1
# Name: area_of_the_terrace, Length: 167, dtype: int64

# %%
df[df["living_area"]<=100].area_of_the_terrace
# Out:
# 0        0.00
# 3        0.00
# 6        0.00
# 7         NaN
# 15        NaN
#          ...
# 78119    0.00
# 78143    0.00
# 78153    2.00
# 78167    5.00
# 78191   28.00
# Name: area_of_the_terrace, Length: 10814, dtype: float64

# %%
df.area_of_the_terrace.describe()
# Out:
# count   22544.00
# mean       11.77
# std        27.72
# min         0.00
# 25%         0.00
# 50%         5.00
# 75%        16.00
# max      2190.00
# Name: area_of_the_terrace, dtype: float64

# %%
df[df["terrace"] == True ].area_of_the_terrace.describe()
# Out:
# count   12641.00
# mean       20.99
# std        34.30
# min         1.00
# 25%         8.00
# 50%        15.00
# 75%        25.00
# max      2190.00
# Name: area_of_the_terrace, dtype: float64

# %%
condition = (df["living_area"] < 100) 
cond2 = (df["living_area"] >= 100) & (df["living_area"] < 150) 
cond3 = (df["living_area"] >= 150) 
df.loc[condition, "area_of_the_terrace"] = df.loc[condition, "area_of_the_terrace"].fillna(10.00)
df.loc[cond2, "area_of_the_terrace"] = df.loc[cond2, "area_of_the_terrace"].fillna(17.00)
df.loc[cond3, "area_of_the_terrace"] = df.loc[cond3, "area_of_the_terrace"].fillna(24.00)

# %%
df.area_of_the_terrace.value_counts(dropna=False)
# Out:
# 0.00      9903
# 24.00     2568
# 10.00     2533
# 17.00     1903
# 20.00      784
#           ...
# 136.00       1
# 185.00       1
# 187.00       1
# 126.00       1
# 98.00        1
# Name: area_of_the_terrace, Length: 166, dtype: int64

# %%
df.area_of_the_terrace.describe()
# Out:
# count   28220.00
# mean       13.01
# std        25.03
# min         0.00
# 25%         0.00
# 50%        10.00
# 75%        20.00
# max      2190.00
# Name: area_of_the_terrace, dtype: float64

# %%
df
# Out:
#       to_rent     price  number_of_rooms  living_area fully_equipped_kitchen  \
# 0        True    485.00             1.00        40.00                   True
# 1        True    790.00             2.00       140.00                   True
# 3        True    520.00             2.00        50.00                   True
# 5        True    640.00             1.00       160.51                   True
# 6        True    660.00             2.00        95.00                   True
# ...       ...       ...              ...          ...                    ...
# 78160    True    920.00             3.00       163.00                   True
# 78167    True    800.00             2.00        86.00                   True
# 78170    True    930.00             3.00       155.00                   True
# 78174   False 529000.00             2.00       134.00                   True
# 78191    True   1590.00             3.00       100.00                   True
#
# ...

# %%
df_c = df.copy

# %%
df.columns
# Out:
# Index(['to_rent', 'price', 'number_of_rooms', 'living_area',
#        'fully_equipped_kitchen', 'furnished', 'open_fire', 'terrace',
#        'area_of_the_terrace', 'garden', 'area_of_the_garden', 'swimming_pool',
#        'state_of_the_building', 'zipcode', 'type'],
#       dtype='object')

# %% [markdown]
# #### <p style="background-color:#F39C12; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">  garden </p>

# %%
df.columns
# Out:
# Index(['to_rent', 'price', 'number_of_rooms', 'living_area',
#        'fully_equipped_kitchen', 'furnished', 'open_fire', 'terrace',
#        'area_of_the_terrace', 'garden', 'area_of_the_garden', 'swimming_pool',
#        'state_of_the_building', 'zipcode', 'type'],
#       dtype='object')

# %%
df.garden.value_counts(dropna=False)
# Out:
# False    20082
# True      8138
# Name: garden, dtype: int64

# %%
df.shape
# Out:
# (28220, 15)

# %% [markdown]
# #### <p style="background-color:#F39C12; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">  area_of_the_garden </p>

# %%
df
# Out:
#       to_rent     price  number_of_rooms  living_area fully_equipped_kitchen  \
# 0        True    485.00             1.00        40.00                   True
# 1        True    790.00             2.00       140.00                   True
# 3        True    520.00             2.00        50.00                   True
# 5        True    640.00             1.00       160.51                   True
# 6        True    660.00             2.00        95.00                   True
# ...       ...       ...              ...          ...                    ...
# 78160    True    920.00             3.00       163.00                   True
# 78167    True    800.00             2.00        86.00                   True
# 78170    True    930.00             3.00       155.00                   True
# 78174   False 529000.00             2.00       134.00                   True
# 78191    True   1590.00             3.00       100.00                   True
#
# ...

# %%
df.area_of_the_garden.value_counts(dropna=False)
# Out:
# 0.00      20082
# NaN        3026
# 100.00      185
# 200.00      159
# 300.00      131
#           ...
# 257.00        1
# 228.00        1
# 321.00        1
# 542.00        1
# 966.00        1
# Name: area_of_the_garden, Length: 806, dtype: int64

# %%
df.area_of_the_garden.describe()
# Out:
# count   25194.00
# mean       92.34
# std      1202.99
# min         0.00
# 25%         0.00
# 50%         0.00
# 75%         0.00
# max     80000.00
# Name: area_of_the_garden, dtype: float64

# %%
condition = (df["living_area"] < 130) 
cond2 = (df["living_area"] >= 130) & (df["living_area"] < 200) 
cond3 = (df["living_area"] >= 200) 
df.loc[condition, "area_of_the_garden"] = df.loc[condition, "area_of_the_garden"].fillna(0.00)
df.loc[cond2, "area_of_the_garden"] = df.loc[cond2, "area_of_the_garden"].fillna(50.00)
df.loc[cond3, "area_of_the_garden"] = df.loc[cond3, "area_of_the_garden"].fillna(95.00)

# %%
df.area_of_the_garden.value_counts(dropna=False)
# Out:
# 0.00      21171
# 50.00      1986
# 100.00      185
# 200.00      159
# 300.00      131
#           ...
# 257.00        1
# 228.00        1
# 321.00        1
# 542.00        1
# 966.00        1
# Name: area_of_the_garden, Length: 805, dtype: int64

# %%
df.area_of_the_garden.describe()
# Out:
# count   28220.00
# mean       85.97
# std      1136.84
# min         0.00
# 25%         0.00
# 50%         0.00
# 75%         0.00
# max     80000.00
# Name: area_of_the_garden, dtype: float64

# %%
df.sample(10)
# Out:
#       to_rent     price  number_of_rooms  living_area fully_equipped_kitchen  \
# 24723   False 220000.00             3.00        76.00                  False
# 39854   False 220000.00             3.00       141.00                  False
# 1356     True    900.00             2.00        61.00                   True
# 52879   False 348000.00             3.00       131.00                   True
# 6558     True    720.00             2.00        86.00                   True
# 61251   False 245000.00             2.00       150.00                   True
# 1298     True   2000.00             2.00       127.00                   True
# 40564   False 420750.00             3.00       197.00                   True
# 53291   False 165000.00             1.00        60.00                   True
# 32428   False 250000.00             3.00        95.00                   True
#
#       furnished  open_fire  terrace  area_of_the_terrace  garden  \
# ...

# %% [markdown]
# #### <p style="background-color:#F39C12; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">  swimming_pool </p>

# %%
df
# Out:
#       to_rent     price  number_of_rooms  living_area fully_equipped_kitchen  \
# 0        True    485.00             1.00        40.00                   True
# 1        True    790.00             2.00       140.00                   True
# 3        True    520.00             2.00        50.00                   True
# 5        True    640.00             1.00       160.51                   True
# 6        True    660.00             2.00        95.00                   True
# ...       ...       ...              ...          ...                    ...
# 78160    True    920.00             3.00       163.00                   True
# 78167    True    800.00             2.00        86.00                   True
# 78170    True    930.00             3.00       155.00                   True
# 78174   False 529000.00             2.00       134.00                   True
# 78191    True   1590.00             3.00       100.00                   True
#
# ...

# %%
df.swimming_pool.value_counts(dropna=False)
# Out:
# False    27912
# True       308
# Name: swimming_pool, dtype: int64

# %%
df.swimming_pool.describe()
# Out:
# count     28220
# unique        2
# top       False
# freq      27912
# Name: swimming_pool, dtype: object

# %% [markdown]
# #### <p style="background-color:#F39C12; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;"> state_of_the_building	 </p>

# %%
df.state_of_the_building.value_counts(dropna=False)
# Out:
# \nBon\n                  9237
# \nExcellentétat\n        7375
# NaN                      6321
# \nÀrafraîchir\n          1835
# \nFraîchementrénové\n    1818
# \nÀrénover\n             1562
# \nÀrestaurer\n             72
# Name: state_of_the_building, dtype: int64

# %%
df["state_of_the_building"] = df["state_of_the_building"].str.strip()

# %%
df.state_of_the_building.value_counts(dropna=False)
# Out:
# Bon                  9237
# Excellentétat        7375
# NaN                  6321
# Àrafraîchir          1835
# Fraîchementrénové    1818
# Àrénover             1562
# Àrestaurer             72
# Name: state_of_the_building, dtype: int64

# %%
df["state_of_the_building"] = df["state_of_the_building"].str.lower()

# %%
df.state_of_the_building.value_counts(dropna=False)
# Out:
# bon                  9237
# excellentétat        7375
# NaN                  6321
# àrafraîchir          1835
# fraîchementrénové    1818
# àrénover             1562
# àrestaurer             72
# Name: state_of_the_building, dtype: int64

# %%
df
# Out:
#       to_rent     price  number_of_rooms  living_area fully_equipped_kitchen  \
# 0        True    485.00             1.00        40.00                   True
# 1        True    790.00             2.00       140.00                   True
# 3        True    520.00             2.00        50.00                   True
# 5        True    640.00             1.00       160.51                   True
# 6        True    660.00             2.00        95.00                   True
# ...       ...       ...              ...          ...                    ...
# 78160    True    920.00             3.00       163.00                   True
# 78167    True    800.00             2.00        86.00                   True
# 78170    True    930.00             3.00       155.00                   True
# 78174   False 529000.00             2.00       134.00                   True
# 78191    True   1590.00             3.00       100.00                   True
#
# ...

# %%
# ortalama yüzdelikleri hesaplamak
total = df["state_of_the_building"].count()
percentages = df["state_of_the_building"].value_counts(normalize=True) * 100

# NaN değerleri ortalama yüzdeliklere göre doldurmak
df["state_of_the_building"] = df["state_of_the_building"].apply(lambda x: x if pd.notnull(x) else np.random.choice(percentages.index, p=percentages/100))

# %%
df.state_of_the_building.value_counts(dropna=False)
# Out:
# bon                  11894
# excellentétat         9498
# fraîchementrénové     2371
# àrafraîchir           2359
# àrénover              2013
# àrestaurer              85
# Name: state_of_the_building, dtype: int64

# %% [markdown]
# #### <p style="background-color:#F39C12; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;"> zipcode </p>

# %%
df
# Out:
#       to_rent     price  number_of_rooms  living_area fully_equipped_kitchen  \
# 0        True    485.00             1.00        40.00                   True
# 1        True    790.00             2.00       140.00                   True
# 3        True    520.00             2.00        50.00                   True
# 5        True    640.00             1.00       160.51                   True
# 6        True    660.00             2.00        95.00                   True
# ...       ...       ...              ...          ...                    ...
# 78160    True    920.00             3.00       163.00                   True
# 78167    True    800.00             2.00        86.00                   True
# 78170    True    930.00             3.00       155.00                   True
# 78174   False 529000.00             2.00       134.00                   True
# 78191    True   1590.00             3.00       100.00                   True
#
# ...

# %%
df.zipcode.value_counts(dropna=False)
# Out:
# 9000    446
# 1000    434
# 1050    433
# 4000    389
# 8400    387
#        ...
# 7534      1
# 3631      1
# 9667      1
# 5362      1
# 9772      1
# Name: zipcode, Length: 990, dtype: int64

# %%
df['zipcode'].isnull().sum()
# Out:
# 0

# %%
df['region'] = np.where(df['zipcode'].between(1000, 1299), 'Brussels',
                                 np.where(df['zipcode'].between(1300, 1499), 'Walloon Brabant',
                                 np.where(df['zipcode'].between(1500, 1999), 'Flemish Brabant',
                                 np.where(df['zipcode'].between(2000, 2999), 'Antwerp',
                                 np.where(df['zipcode'].between(3000, 3499), 'Flemish Region',
                                 np.where(df['zipcode'].between(3500, 3999), 'Limburg',
                                 np.where(df['zipcode'].between(4000, 4999), 'Liège',
                                 np.where(df['zipcode'].between(5000, 5999), 'Namur',
                                 np.where(df['zipcode'].between(6000, 6599), 'Hainaut',
                                 np.where(df['zipcode'].between(6600, 6999), 'Luxembourg',
                                 np.where(df['zipcode'].between(7000, 8999), 'Walloon Region',
                                 np.where(df['zipcode'].between(9000, 9999), 'East Flanders', 'Other'))))))))))))

# %%
df
# Out:
#       to_rent     price  number_of_rooms  living_area fully_equipped_kitchen  \
# 0        True    485.00             1.00        40.00                   True
# 1        True    790.00             2.00       140.00                   True
# 3        True    520.00             2.00        50.00                   True
# 5        True    640.00             1.00       160.51                   True
# 6        True    660.00             2.00        95.00                   True
# ...       ...       ...              ...          ...                    ...
# 78160    True    920.00             3.00       163.00                   True
# 78167    True    800.00             2.00        86.00                   True
# 78170    True    930.00             3.00       155.00                   True
# 78174   False 529000.00             2.00       134.00                   True
# 78191    True   1590.00             3.00       100.00                   True
#
# ...

# %%
df.region.value_counts(dropna=False)
# Out:
# Walloon Region     6412
# Antwerp            4682
# East Flanders      3277
# Liège              2721
# Brussels           2665
# Walloon Brabant    1440
# Flemish Brabant    1382
# Hainaut            1294
# Namur              1291
# Limburg            1213
# Flemish Region     1072
# Luxembourg          770
# Other                 1
# Name: region, dtype: int64

# %%
df['region_be'] = np.where(df['region'].isin(['Hainaut' , 'Walloon Region', 'Liège', 'Luxembourg', 'Namur', 'Walloon Brabant']), 'Region Walloonie',
np.where(df['region'].isin(['Antwerp','East Flanders','Flemish Brabant','Limburg','Flemish Region']),'Region Flanders','Brussels'))

# %%
df
# Out:
#       to_rent     price  number_of_rooms  living_area fully_equipped_kitchen  \
# 0        True    485.00             1.00        40.00                   True
# 1        True    790.00             2.00       140.00                   True
# 3        True    520.00             2.00        50.00                   True
# 5        True    640.00             1.00       160.51                   True
# 6        True    660.00             2.00        95.00                   True
# ...       ...       ...              ...          ...                    ...
# 78160    True    920.00             3.00       163.00                   True
# 78167    True    800.00             2.00        86.00                   True
# 78170    True    930.00             3.00       155.00                   True
# 78174   False 529000.00             2.00       134.00                   True
# 78191    True   1590.00             3.00       100.00                   True
#
# ...

# %%
df.drop('region', axis=1)
# Out:
#       to_rent     price  number_of_rooms  living_area fully_equipped_kitchen  \
# 0        True    485.00             1.00        40.00                   True
# 1        True    790.00             2.00       140.00                   True
# 3        True    520.00             2.00        50.00                   True
# 5        True    640.00             1.00       160.51                   True
# 6        True    660.00             2.00        95.00                   True
# ...       ...       ...              ...          ...                    ...
# 78160    True    920.00             3.00       163.00                   True
# 78167    True    800.00             2.00        86.00                   True
# 78170    True    930.00             3.00       155.00                   True
# 78174   False 529000.00             2.00       134.00                   True
# 78191    True   1590.00             3.00       100.00                   True
#
# ...

# %%
df.region_be.value_counts(dropna=False)
# Out:
# Region Walloonie    13928
# Region Flanders     11626
# Brussels             2666
# Name: region_be, dtype: int64

# %% [markdown]
# #### <p style="background-color:#F39C12; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;"> type </p>

# %%
df.type.value_counts(dropna=False)
# Out:
# Appartement             12700
# Maison                  10124
# Duplex                   1065
# Rez-de-chaussée           902
# Villa                     720
# Penthouse                 676
# Immeuble                  311
# Appartementdeservice      302
# Immeublemixte             274
# Studio                    216
# Maisonbel-étage           179
# Bungalow                  152
# Loft                      117
# Bienexceptionnel          111
# Maisondecampagne           74
# Triplex                    66
# Maisondemaître             64
# Chalet                     57
# Autresbiens                38
# Logementétudiant           38
# Ferme                      17
# Manoir                     15
# Château                     2
# Name: type, dtype: int64

# %%
df.type.describe()
# Out:
# count           28220
# unique             23
# top       Appartement
# freq            12700
# Name: type, dtype: object

# %% [markdown]
# ## <p style="background-color:#16A085; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Step 3 : Data Frame Chechk </p>

# %%
df
# Out:
#       to_rent     price  number_of_rooms  living_area fully_equipped_kitchen  \
# 0        True    485.00             1.00        40.00                   True
# 1        True    790.00             2.00       140.00                   True
# 3        True    520.00             2.00        50.00                   True
# 5        True    640.00             1.00       160.51                   True
# 6        True    660.00             2.00        95.00                   True
# ...       ...       ...              ...          ...                    ...
# 78160    True    920.00             3.00       163.00                   True
# 78167    True    800.00             2.00        86.00                   True
# 78170    True    930.00             3.00       155.00                   True
# 78174   False 529000.00             2.00       134.00                   True
# 78191    True   1590.00             3.00       100.00                   True
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 28220 entries, 0 to 78191
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   to_rent                 28220 non-null  object
#  1   price                   28220 non-null  float64
#  2   number_of_rooms         28220 non-null  float64
#  3   living_area             28220 non-null  float64
#  4   fully_equipped_kitchen  28220 non-null  object
#  5   furnished               28220 non-null  object
#  6   open_fire               28220 non-null  bool
#  7   terrace                 28220 non-null  bool
#  8   area_of_the_terrace     28220 non-null  float64
#  9   garden                  28220 non-null  bool
#  10  area_of_the_garden      28220 non-null  float64
#  11  swimming_pool           28220 non-null  bool
#  12  state_of_the_building   28220 non-null  object
#  13  zipcode                 28220 non-null  int64
# ...

# %%
df.describe()
# Out:
#           price  number_of_rooms  living_area  area_of_the_terrace  \
# count  28220.00         28220.00     28220.00             28220.00
# mean  215023.44             2.43       120.67                13.01
# std   181848.75             0.99        40.88                25.03
# min       95.00             1.00        20.00                 0.00
# 25%     1500.00             2.00        87.00                 0.00
# 50%   219925.00             2.00       118.00                10.00
# 75%   325000.00             3.00       160.51                20.00
# max   999999.00            10.00       200.00              2190.00
#
#        area_of_the_garden  zipcode
# count            28220.00 28220.00
# mean                85.97  5001.82
# std               1136.84  2943.95
# min                  0.00   236.00
# 25%                  0.00  2200.00
# 50%                  0.00  4480.00
# 75%                  0.00  8210.00
# max              80000.00  9992.00

# %%
df.columns
# Out:
# Index(['to_rent', 'price', 'number_of_rooms', 'living_area',
#        'fully_equipped_kitchen', 'furnished', 'open_fire', 'terrace',
#        'area_of_the_terrace', 'garden', 'area_of_the_garden', 'swimming_pool',
#        'state_of_the_building', 'zipcode', 'type', 'region', 'region_be'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# to_rent                   0
# price                     0
# number_of_rooms           0
# living_area               0
# fully_equipped_kitchen    0
# furnished                 0
# open_fire                 0
# terrace                   0
# area_of_the_terrace       0
# garden                    0
# area_of_the_garden        0
# swimming_pool             0
# state_of_the_building     0
# zipcode                   0
# type                      0
# region                    0
# region_be                 0
# dtype: int64

# %% [markdown]
# ## <p style="background-color:#2C3E50; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Step 4 : Small Look Cleaned Data Set If there is more needed </p>

# %%
# importing necessary libraries
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt

# %%
# Reading my cleaned data set 
df = pd.read_csv("cleaned_data2.csv")

# %%
df = df.drop('Unnamed: 0', axis=1)
df
# Out:
#        to_rent     price  number_of_rooms  living_area  \
# 0         True    485.00             1.00        40.00
# 1         True    790.00             2.00       140.00
# 2         True    520.00             2.00        50.00
# 3         True    640.00             1.00       160.51
# 4         True    660.00             2.00        95.00
# ...        ...       ...              ...          ...
# 28215     True    920.00             3.00       163.00
# 28216     True    800.00             2.00        86.00
# 28217     True    930.00             3.00       155.00
# 28218    False 529000.00             2.00       134.00
# 28219     True   1590.00             3.00       100.00
#
#        fully_equipped_kitchen  furnished  open_fire  terrace  \
# 0                        True      False      False    False
# 1                        True      False      False    False
# 2                        True      False      False    False
# ...

# %%
df.describe()
# Out:
#           price  number_of_rooms  living_area  area_of_the_terrace  \
# count  28220.00         28220.00     28220.00             28220.00
# mean  215023.44             2.43       120.67                13.01
# std   181848.75             0.99        40.88                25.03
# min       95.00             1.00        20.00                 0.00
# 25%     1500.00             2.00        87.00                 0.00
# 50%   219925.00             2.00       118.00                10.00
# 75%   325000.00             3.00       160.51                20.00
# max   999999.00            10.00       200.00              2190.00
#
#        area_of_the_garden  zipcode
# count            28220.00 28220.00
# mean                85.97  5001.82
# std               1136.84  2943.95
# min                  0.00   236.00
# 25%                  0.00  2200.00
# 50%                  0.00  4480.00
# 75%                  0.00  8210.00
# max              80000.00  9992.00

# %%
df.groupby("region_be")['price'].describe()
# Out:
#                     count      mean       std    min     25%       50%  \
# region_be
# Brussels          2666.00 175307.52 229301.38 500.00 1360.00   2500.00
# Region Flanders  11626.00 240085.53 180007.41 125.00 1585.25 259000.00
# Region Walloonie 13928.00 201705.72 169979.02  95.00 2287.50 195000.00
#
#                        75%       max
# region_be
# Brussels         329000.00 999999.00
# Region Flanders  350000.00 999000.00
# Region Walloonie 294000.00 999000.00

# %%
# Creating Rent and Sale 
Rent = df[df['to_rent'] == True]
Sale = df[df['to_rent'] == False]

# %% [markdown]
# ### SALE

# %%
Sale
# Out:
#        to_rent     price  number_of_rooms  living_area  \
# 6438     False 175000.00             1.00        50.00
# 6439     False 386865.00             3.00       179.00
# 6440     False 330435.00             3.00       144.00
# 6441     False 288160.00             3.00       133.00
# 6442     False 288160.00             3.00       133.00
# ...        ...       ...              ...          ...
# 28205    False 245000.00             5.00       180.00
# 28209    False 479000.00             5.00       150.00
# 28212    False 360000.00             4.00       180.00
# 28214    False 325000.00             2.00       109.00
# 28218    False 529000.00             2.00       134.00
#
#        fully_equipped_kitchen  furnished  open_fire  terrace  \
# 6438                     True      False      False     True
# 6439                     True      False      False    False
# 6440                     True      False      False    False
# ...

# %%
sale_byregion_mean = Sale.groupby("region_be")['price'].mean()
sale_byregion_mean
# Out:
# region_be
# Brussels           386632.73
# Region Flanders    324529.98
# Region Walloonie   266450.96
# Name: price, dtype: float64

# %%
Sale.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20324 entries, 6438 to 28218
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   to_rent                 20324 non-null  bool
#  1   price                   20324 non-null  float64
#  2   number_of_rooms         20324 non-null  float64
#  3   living_area             20324 non-null  float64
#  4   fully_equipped_kitchen  20324 non-null  bool
#  5   furnished               20324 non-null  bool
#  6   open_fire               20324 non-null  bool
#  7   terrace                 20324 non-null  bool
#  8   area_of_the_terrace     20324 non-null  float64
#  9   garden                  20324 non-null  bool
#  10  area_of_the_garden      20324 non-null  float64
#  11  swimming_pool           20324 non-null  bool
#  12  state_of_the_building   20324 non-null  object
#  13  zipcode                 20324 non-null  int64
# ...

# %%
Sale.groupby("region_be")['price'].describe()
# Out:
#                     count      mean       std     min       25%       50%  \
# region_be
# Brussels          1200.00 386632.73 186424.51 1000.00 249750.00 350000.00
# Region Flanders   8591.00 324529.98 128568.77 1016.00 239000.00 299000.00
# Region Walloonie 10533.00 266450.96 144939.18 1000.00 171500.00 240000.00
#
#                        75%       max
# region_be
# Brussels         499000.00 999000.00
# Region Flanders  385000.00 999000.00
# Region Walloonie 325000.00 999000.00

# %%
Sale['price'].sort_values(ascending=True)
# Out:
# 13207     1000.00
# 13467     1000.00
# 9397      1000.00
# 13073     1000.00
# 27567     1016.00
#            ...
# 24459   995000.00
# 24592   999000.00
# 8920    999000.00
# 25380   999000.00
# 11283   999000.00
# Name: price, Length: 20324, dtype: float64

# %%
# Deleted all the listings who is smaller than 40.000 because it's not possible 
Sale = Sale[Sale.price > 40000]

# %%
Sale['price'].sort_values(ascending=True)
# Out:
# 8259     44000.00
# 21199    45000.00
# 7227     45000.00
# 17311    45000.00
# 9028     45000.00
#            ...
# 15937   995000.00
# 24592   999000.00
# 8920    999000.00
# 11283   999000.00
# 25380   999000.00
# Name: price, Length: 20055, dtype: float64

# %%
Sale.groupby("region_be")['price'].describe()
# Out:
#                     count      mean       std      min       25%       50%  \
# region_be
# Brussels          1161.00 399576.45 175393.96 95000.00 260000.00 360000.00
# Region Flanders   8520.00 327220.52 125664.89 49000.00 240000.00 299925.00
# Region Walloonie 10374.00 270463.94 142341.68 44000.00 175000.00 245000.00
#
#                        75%       max
# region_be
# Brussels         499000.00 999000.00
# Region Flanders  385000.00 999000.00
# Region Walloonie 325000.00 999000.00

# %%
sale_byregion_mean
# Out:
# region_be
# Brussels           386632.73
# Region Flanders    324529.98
# Region Walloonie   266450.96
# Name: price, dtype: float64

# %% [markdown]
# ### Rent

# %%
Rent
# Out:
#        to_rent   price  number_of_rooms  living_area  fully_equipped_kitchen  \
# 0         True  485.00             1.00        40.00                    True
# 1         True  790.00             2.00       140.00                    True
# 2         True  520.00             2.00        50.00                    True
# 3         True  640.00             1.00       160.51                    True
# 4         True  660.00             2.00        95.00                    True
# ...        ...     ...              ...          ...                     ...
# 28213     True  880.00             1.00        68.00                    True
# 28215     True  920.00             3.00       163.00                    True
# 28216     True  800.00             2.00        86.00                    True
# 28217     True  930.00             3.00       155.00                    True
# 28219     True 1590.00             3.00       100.00                    True
#
# ...

# %%
# calculating the avarage rents for regions 
rent_byregion_mean = Rent.groupby("region_be")['price'].mean()
rent_byregion_mean
# Out:
# region_be
# Brussels           2326.44
# Region Flanders    1053.50
# Region Walloonie    833.38
# Name: price, dtype: float64

# %%
Rent.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7896 entries, 0 to 28219
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   to_rent                 7896 non-null   bool
#  1   price                   7896 non-null   float64
#  2   number_of_rooms         7896 non-null   float64
#  3   living_area             7896 non-null   float64
#  4   fully_equipped_kitchen  7896 non-null   bool
#  5   furnished               7896 non-null   bool
#  6   open_fire               7896 non-null   bool
#  7   terrace                 7896 non-null   bool
#  8   area_of_the_terrace     7896 non-null   float64
#  9   garden                  7896 non-null   bool
#  10  area_of_the_garden      7896 non-null   float64
#  11  swimming_pool           7896 non-null   bool
#  12  state_of_the_building   7896 non-null   object
#  13  zipcode                 7896 non-null   int64
# ...

# %%
Rent.describe()
# Out:
#           price  number_of_rooms  living_area  area_of_the_terrace  \
# count   7896.00          7896.00      7896.00              7896.00
# mean    1195.19             2.03       108.12                10.86
# std    11358.58             0.83        39.43                29.66
# min       95.00             1.00        20.00                 0.00
# 25%      740.00             1.00        80.00                 0.00
# 50%      880.00             2.00       100.00                 8.00
# 75%     1195.00             2.00       144.00                17.00
# max   999999.00             7.00       200.00              2190.00
#
#        area_of_the_garden  zipcode
# count             7896.00  7896.00
# mean                33.89  4601.66
# std                385.94  3065.19
# min                  0.00  1000.00
# 25%                  0.00  1731.00
# 50%                  0.00  4000.00
# 75%                  0.00  7860.00
# max              20000.00  9992.00

# %%
Rent['price'].sort_values(ascending=True)
# Out:
# 25782       95.00
# 28040      125.00
# 294        250.00
# 295        250.00
# 391        275.00
#            ...
# 500       7000.00
# 25263    13000.00
# 2248     66000.00
# 5643    120120.00
# 4600    999999.00
# Name: price, Length: 7896, dtype: float64

# %%
Rent = Rent[Rent.price > 150]

# %%
Rent.price.sort_values(ascending=False)
# Out:
# 4600    999999.00
# 5643    120120.00
# 2248     66000.00
# 25263    13000.00
# 500       7000.00
#            ...
# 381        300.00
# 6132       300.00
# 391        275.00
# 295        250.00
# 294        250.00
# Name: price, Length: 7894, dtype: float64

# %%
rent_byregion_mean
# Out:
# region_be
# Brussels           2326.44
# Region Flanders    1053.50
# Region Walloonie    833.38
# Name: price, dtype: float64

# %%
Rent.describe()
# Out:
#           price  number_of_rooms  living_area  area_of_the_terrace  \
# count   7894.00          7894.00      7894.00              7894.00
# mean    1195.47             2.03       108.10                10.86
# std    11360.01             0.83        39.42                29.66
# min      250.00             1.00        20.00                 0.00
# 25%      740.00             1.00        80.00                 0.00
# 50%      880.00             2.00       100.00                 8.00
# 75%     1195.00             2.00       144.00                17.00
# max   999999.00             7.00       200.00              2190.00
#
#        area_of_the_garden  zipcode
# count             7894.00  7894.00
# mean                33.90  4601.43
# std                385.99  3065.13
# min                  0.00  1000.00
# 25%                  0.00  1731.00
# 50%                  0.00  4000.00
# 75%                  0.00  7857.50
# max              20000.00  9992.00

# %%
Rent = Rent[Rent.price < 10000]

# %%
Rent.describe()
# Out:
#         price  number_of_rooms  living_area  area_of_the_terrace  \
# count 7890.00          7890.00      7890.00              7890.00
# mean  1044.09             2.03       108.08                10.86
# std    542.07             0.82        39.42                29.67
# min    250.00             1.00        20.00                 0.00
# 25%    740.00             1.00        80.00                 0.00
# 50%    880.00             2.00       100.00                 8.00
# 75%   1193.75             2.00       144.00                17.00
# max   7000.00             7.00       200.00              2190.00
#
#        area_of_the_garden  zipcode
# count             7890.00  7890.00
# mean                33.91  4601.86
# std                386.08  3064.77
# min                  0.00  1000.00
# 25%                  0.00  1731.00
# 50%                  0.00  4000.00
# 75%                  0.00  7857.50
# max              20000.00  9992.00

# %%
# calculating the avarage rents for regions 
rent_byregion_mean = Rent.groupby("region_be")['price'].mean()
rent_byregion_mean
# Out:
# region_be
# Brussels           1645.44
# Region Flanders     989.15
# Region Walloonie    833.59
# Name: price, dtype: float64

# %%
Rent
# Out:
#        to_rent   price  number_of_rooms  living_area  fully_equipped_kitchen  \
# 0         True  485.00             1.00        40.00                    True
# 1         True  790.00             2.00       140.00                    True
# 2         True  520.00             2.00        50.00                    True
# 3         True  640.00             1.00       160.51                    True
# 4         True  660.00             2.00        95.00                    True
# ...        ...     ...              ...          ...                     ...
# 28213     True  880.00             1.00        68.00                    True
# 28215     True  920.00             3.00       163.00                    True
# 28216     True  800.00             2.00        86.00                    True
# 28217     True  930.00             3.00       155.00                    True
# 28219     True 1590.00             3.00       100.00                    True
#
# ...

# %%
df
# Out:
#        to_rent     price  number_of_rooms  living_area  \
# 0         True    485.00             1.00        40.00
# 1         True    790.00             2.00       140.00
# 2         True    520.00             2.00        50.00
# 3         True    640.00             1.00       160.51
# 4         True    660.00             2.00        95.00
# ...        ...       ...              ...          ...
# 28215     True    920.00             3.00       163.00
# 28216     True    800.00             2.00        86.00
# 28217     True    930.00             3.00       155.00
# 28218    False 529000.00             2.00       134.00
# 28219     True   1590.00             3.00       100.00
#
#        fully_equipped_kitchen  furnished  open_fire  terrace  \
# 0                        True      False      False    False
# 1                        True      False      False    False
# 2                        True      False      False    False
# ...

# %%
df.columns
# Out:
# Index(['to_rent', 'price', 'number_of_rooms', 'living_area',
#        'fully_equipped_kitchen', 'furnished', 'open_fire', 'terrace',
#        'area_of_the_terrace', 'garden', 'area_of_the_garden', 'swimming_pool',
#        'state_of_the_building', 'zipcode', 'type', 'region_be'],
#       dtype='object')

# %%
df
# Out:
#        to_rent     price  number_of_rooms  living_area  \
# 0         True    485.00             1.00        40.00
# 1         True    790.00             2.00       140.00
# 2         True    520.00             2.00        50.00
# 3         True    640.00             1.00       160.51
# 4         True    660.00             2.00        95.00
# ...        ...       ...              ...          ...
# 28215     True    920.00             3.00       163.00
# 28216     True    800.00             2.00        86.00
# 28217     True    930.00             3.00       155.00
# 28218    False 529000.00             2.00       134.00
# 28219     True   1590.00             3.00       100.00
#
#        fully_equipped_kitchen  furnished  open_fire  terrace  \
# 0                        True      False      False    False
# 1                        True      False      False    False
# 2                        True      False      False    False
# ...

# %%
df.isnull().sum()
# Out:
# to_rent                   0
# price                     0
# number_of_rooms           0
# living_area               0
# fully_equipped_kitchen    0
# furnished                 0
# open_fire                 0
# terrace                   0
# area_of_the_terrace       0
# garden                    0
# area_of_the_garden        0
# swimming_pool             0
# state_of_the_building     0
# zipcode                   0
# type                      0
# region_be                 0
# dtype: int64

# %%
df.describe()
# Out:
#           price  number_of_rooms  living_area  area_of_the_terrace  \
# count  28220.00         28220.00     28220.00             28220.00
# mean  215023.44             2.43       120.67                13.01
# std   181848.75             0.99        40.88                25.03
# min       95.00             1.00        20.00                 0.00
# 25%     1500.00             2.00        87.00                 0.00
# 50%   219925.00             2.00       118.00                10.00
# 75%   325000.00             3.00       160.51                20.00
# max   999999.00            10.00       200.00              2190.00
#
#        area_of_the_garden  zipcode
# count            28220.00 28220.00
# mean                85.97  5001.82
# std               1136.84  2943.95
# min                  0.00   236.00
# 25%                  0.00  2200.00
# 50%                  0.00  4480.00
# 75%                  0.00  8210.00
# max              80000.00  9992.00

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28220 entries, 0 to 28219
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   to_rent                 28220 non-null  bool
#  1   price                   28220 non-null  float64
#  2   number_of_rooms         28220 non-null  float64
#  3   living_area             28220 non-null  float64
#  4   fully_equipped_kitchen  28220 non-null  bool
#  5   furnished               28220 non-null  bool
#  6   open_fire               28220 non-null  bool
#  7   terrace                 28220 non-null  bool
#  8   area_of_the_terrace     28220 non-null  float64
#  9   garden                  28220 non-null  bool
#  10  area_of_the_garden      28220 non-null  float64
#  11  swimming_pool           28220 non-null  bool
#  12  state_of_the_building   28220 non-null  object
#  13  zipcode                 28220 non-null  int64
# ...

# %%
df = df.reset_index(drop=True)

# %%
df.T
# Out:
#                                    0                1                 2      \
# to_rent                             True             True              True
# price                             485.00           790.00            520.00
# number_of_rooms                     1.00             2.00              2.00
# living_area                        40.00           140.00             50.00
# fully_equipped_kitchen              True             True              True
# furnished                          False            False             False
# open_fire                          False            False             False
# terrace                            False            False             False
# area_of_the_terrace                 0.00             0.00              0.00
# garden                             False            False             False
# area_of_the_garden                  0.00             0.00              0.00
# ...

# %%
df.to_csv('cleaned_data2.csv')

# %% [markdown]
# ## <p style="background-color:#2C3E50; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Step 5 : Data Analysis </p>

# %% [markdown]
# Now that the data has been collected and cleaned, it is time for the analysis. How many variables and inputs do you have? And so on...
#
# Use the tools such as matplotlib / seaborn / plotly. Take the time to play with those libraries before starting.
#
# Answer the Folllowing questions with a vizualization if appropriate:
#
# <ul>
#   <li>How many rows and columns?</li>
#   <li>What is the correlation between the variables and the price? (Why might that be?)</li>
#   <li>How are variables correlated to each other? (Why?)</li>
#   <li>Which variables have the greatest influence on the price?</li>
#   <li>Which variables have the least influence on the price?</li>
#   <li>How many qualitative and quantitative variables are there? How would you transform these values into numerical values?</li>
#   <li>What is the percentage of missing values per column?</li>
# </ul>

# %% [markdown]
# ### <p style="background-color:blue; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:15px 10px;">How many rows and columns?</p>

# %%
merged_df = pd.concat([Rent, Sale])
merged_df
# Out:
#        to_rent     price  number_of_rooms  living_area  \
# 0         True    485.00             1.00        40.00
# 1         True    790.00             2.00       140.00
# 2         True    520.00             2.00        50.00
# 3         True    640.00             1.00       160.51
# 4         True    660.00             2.00        95.00
# ...        ...       ...              ...          ...
# 28205    False 245000.00             5.00       180.00
# 28209    False 479000.00             5.00       150.00
# 28212    False 360000.00             4.00       180.00
# 28214    False 325000.00             2.00       109.00
# 28218    False 529000.00             2.00       134.00
#
#        fully_equipped_kitchen  furnished  open_fire  terrace  \
# 0                        True      False      False    False
# 1                        True      False      False    False
# 2                        True      False      False    False
# ...

# %%
merged_df.shape
# Out:
# (27945, 16)

# %% [markdown]
# ### <p style="background-color:blue; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:15px 10px;">What is the correlation between the variables and the price? (Why might that be?)</p>

# %% [markdown]
# What is the correlation between the variables and the price? (Why might that be?)

# %%
correlation = merged_df.corr()
correlation['price']
# Out:
# to_rent                  -0.75
# price                     1.00
# number_of_rooms           0.35
# living_area               0.34
# fully_equipped_kitchen    0.02
# furnished                -0.12
# open_fire                 0.09
# terrace                   0.10
# area_of_the_terrace       0.13
# garden                    0.19
# area_of_the_garden        0.03
# swimming_pool             0.06
# zipcode                  -0.01
# Name: price, dtype: float64

# %%
correlation_Rent = Rent.corr()
correlation_Rent['price']
# Out:
# to_rent                    NaN
# price                     1.00
# number_of_rooms           0.37
# living_area               0.37
# fully_equipped_kitchen    0.04
# furnished                 0.24
# open_fire                 0.09
# terrace                   0.21
# area_of_the_terrace       0.17
# garden                    0.08
# area_of_the_garden        0.06
# swimming_pool             0.11
# zipcode                  -0.41
# Name: price, dtype: float64

# %%
correlation_Sale = Sale.corr()
correlation_Sale['price']
# Out:
# to_rent                    NaN
# price                     1.00
# number_of_rooms           0.28
# living_area               0.36
# fully_equipped_kitchen    0.17
# furnished                 0.04
# open_fire                 0.09
# terrace                   0.15
# area_of_the_terrace       0.17
# garden                    0.08
# area_of_the_garden        0.01
# swimming_pool             0.08
# zipcode                  -0.12
# Name: price, dtype: float64

# %% [markdown]
# ###  <p style="background-color:blue; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:15px 10px;">Which variables have the greatest influence on the price?</p>

# %%
correlation = merged_df.corr()
correlation['price']
# Out:
# to_rent                  -0.75
# price                     1.00
# number_of_rooms           0.35
# living_area               0.34
# fully_equipped_kitchen    0.02
# furnished                -0.12
# open_fire                 0.09
# terrace                   0.10
# area_of_the_terrace       0.13
# garden                    0.19
# area_of_the_garden        0.03
# swimming_pool             0.06
# zipcode                  -0.01
# Name: price, dtype: float64

# %%
Correlation_sorted = correlation['price'].sort_values(ascending=False)
Correlation_sorted
# Out:
# price                     1.00
# number_of_rooms           0.35
# living_area               0.34
# garden                    0.19
# area_of_the_terrace       0.13
# terrace                   0.10
# open_fire                 0.09
# swimming_pool             0.06
# area_of_the_garden        0.03
# fully_equipped_kitchen    0.02
# zipcode                  -0.01
# furnished                -0.12
# to_rent                  -0.75
# Name: price, dtype: float64

# %%
Correlation_sorted_rent = correlation_Rent['price'].sort_values(ascending=False)
Correlation_sorted_rent
# Out:
# price                     1.00
# living_area               0.37
# number_of_rooms           0.37
# furnished                 0.24
# terrace                   0.21
# area_of_the_terrace       0.17
# swimming_pool             0.11
# open_fire                 0.09
# garden                    0.08
# area_of_the_garden        0.06
# fully_equipped_kitchen    0.04
# zipcode                  -0.41
# to_rent                    NaN
# Name: price, dtype: float64

# %%
Correlation_sorted_Sale = correlation_Sale['price'].sort_values(ascending=False)
Correlation_sorted_Sale
# Out:
# price                     1.00
# living_area               0.36
# number_of_rooms           0.28
# area_of_the_terrace       0.17
# fully_equipped_kitchen    0.17
# terrace                   0.15
# open_fire                 0.09
# garden                    0.08
# swimming_pool             0.08
# furnished                 0.04
# area_of_the_garden        0.01
# zipcode                  -0.12
# to_rent                    NaN
# Name: price, dtype: float64

# %% [markdown]
# ### <p style="background-color:blue; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:15px 10px;">Which variables have the least influence on the price?</p>

# %%
Correlation_sorted_Sale = correlation_Sale['price'].sort_values(ascending=True)
Correlation_sorted_Sale
# Out:
# zipcode                  -0.12
# area_of_the_garden        0.01
# furnished                 0.04
# swimming_pool             0.08
# garden                    0.08
# open_fire                 0.09
# terrace                   0.15
# fully_equipped_kitchen    0.17
# area_of_the_terrace       0.17
# number_of_rooms           0.28
# living_area               0.36
# price                     1.00
# to_rent                    NaN
# Name: price, dtype: float64

# %%
Correlation_sorted_rent = correlation_Rent['price'].sort_values(ascending=True)
Correlation_sorted_rent
# Out:
# zipcode                  -0.41
# fully_equipped_kitchen    0.04
# area_of_the_garden        0.06
# garden                    0.08
# open_fire                 0.09
# swimming_pool             0.11
# area_of_the_terrace       0.17
# terrace                   0.21
# furnished                 0.24
# number_of_rooms           0.37
# living_area               0.37
# price                     1.00
# to_rent                    NaN
# Name: price, dtype: float64

# %%
Correlation_sorted_rent[1:2]
# Out:
# fully_equipped_kitchen   0.04
# Name: price, dtype: float64

# %%
Correlation_sorted_Sale[1:2]
# Out:
# area_of_the_garden   0.01
# Name: price, dtype: float64

# %% [markdown]
# ### <p style="background-color:blue; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:15px 10px;">How many qualitative and quantitative variables are there? How would you transform these values into numerical values?</p>

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 27945 entries, 0 to 28218
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   to_rent                 27945 non-null  bool
#  1   price                   27945 non-null  float64
#  2   number_of_rooms         27945 non-null  float64
#  3   living_area             27945 non-null  float64
#  4   fully_equipped_kitchen  27945 non-null  bool
#  5   furnished               27945 non-null  bool
#  6   open_fire               27945 non-null  bool
#  7   terrace                 27945 non-null  bool
#  8   area_of_the_terrace     27945 non-null  float64
#  9   garden                  27945 non-null  bool
#  10  area_of_the_garden      27945 non-null  float64
#  11  swimming_pool           27945 non-null  bool
#  12  state_of_the_building   27945 non-null  object
#  13  zipcode                 27945 non-null  int64
# ...

# %%
print ('We have number of dtypes as : bool(7), float64(5), int64(1), object(3)' )
# Out:
# We have number of dtypes as : bool(7), float64(5), int64(1), object(3)

# %% [markdown]
# ### <p style="background-color:blue; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:15px 10px;">What is the percentage of missing values per column?</p>

# %% [markdown]
# BEFORE

# %% [markdown]
# <img src="https://i.hizliresim.com/l52uo7q.png" style="width: 400px; height: 400px" >

# %% [markdown]
# <img src="https://i.hizliresim.com/jw38j42.png" style="width: 300px; height: 300px" >

# %% [markdown]
# NOW

# %%
df.isnull().sum()
# Out:
# to_rent                   0
# price                     0
# number_of_rooms           0
# living_area               0
# fully_equipped_kitchen    0
# furnished                 0
# open_fire                 0
# terrace                   0
# area_of_the_terrace       0
# garden                    0
# area_of_the_garden        0
# swimming_pool             0
# state_of_the_building     0
# zipcode                   0
# type                      0
# region_be                 0
# dtype: int64

# %%
df.isnull().sum()*100 / df.shape[0]
# Out:
# to_rent                  0.00
# price                    0.00
# number_of_rooms          0.00
# living_area              0.00
# fully_equipped_kitchen   0.00
# furnished                0.00
# open_fire                0.00
# terrace                  0.00
# area_of_the_terrace      0.00
# garden                   0.00
# area_of_the_garden       0.00
# swimming_pool            0.00
# state_of_the_building    0.00
# zipcode                  0.00
# type                     0.00
# region_be                0.00
# dtype: float64

# %% [markdown]
# ## <p style="background-color:#8B8B00; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Step 6 : Data Interpretation</p>

# %% [markdown]
# <p dir="auto">After analyzing your data, it's finally time to interpret your results. You have to communicate your analysis using simple words and a table or graph, then use the results to decide on your best course of action.</p>
# <p dir="auto">For starting, you <strong>must</strong> be able to answer :</p>
# <ul dir="auto">
# <li>Plot the outliers.</li>
# <li>Which variables would you delete and why ?</li>
# <li>Represent the number of properties according to their surface using a histogram.</li>
# <li>In your opinion, which 5 variables are the most important and why?</li>
# <li>What are the <strong>most</strong> expensive municipalities in Belgium? (Average price, median price, price per square meter)</li>
# <li>What are the <strong>most</strong> expensive municipalities in Wallonia? (Average price, median price, price per square meter)</li>
# <li>What are the <strong>most</strong> expensive municipalities in Flanders? (Average price, median price, price per square meter)</li>
# <li>What are the <strong>less</strong> expensive municipalities in Belgium? (Average price, median price, price per square meter)</li>
# <li>What are the <strong>less</strong> expensive municipalities in Wallonia? (Average price, median price, price per square meter)</li>
# <li>What are the <strong>less</strong> expensive municipalities in Flanders? (Average price, median price, price per square meter)</li>
# </ul>

# %% [markdown]
# ### <p style="background-color:blue; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:15px 10px;">Plot the Outliers</p>

# %%
merged_df ['price_perm2'] = (merged_df['price'] / merged_df['living_area'])

# %%
# Creating Rent and Sale 
Rent = merged_df[merged_df['to_rent'] == True]
Sale = merged_df[merged_df['to_rent'] == False]

# %%
merged_df
# Out:
#        to_rent     price  number_of_rooms  living_area  \
# 0         True    485.00             1.00        40.00
# 1         True    790.00             2.00       140.00
# 2         True    520.00             2.00        50.00
# 3         True    640.00             1.00       160.51
# 4         True    660.00             2.00        95.00
# ...        ...       ...              ...          ...
# 28205    False 245000.00             5.00       180.00
# 28209    False 479000.00             5.00       150.00
# 28212    False 360000.00             4.00       180.00
# 28214    False 325000.00             2.00       109.00
# 28218    False 529000.00             2.00       134.00
#
#        fully_equipped_kitchen  furnished  open_fire  terrace  \
# 0                        True      False      False    False
# 1                        True      False      False    False
# 2                        True      False      False    False
# ...

# %%
merged_df.price.describe()
# Out:
# count    27945.00
# mean    217064.16
# std     181467.71
# min        250.00
# 25%       1590.00
# 50%     220000.00
# 75%     325000.00
# max     999000.00
# Name: price, dtype: float64

# %%
# Box Plot For RENT PRİCES 
import seaborn as sns
sns.boxplot(data=Rent, x='price', showfliers=True);

# %% [markdown]
# as you can see our median is nearly 850-900 and we have many outliers but I will delete the outliers which is more than 4500 because in the past I also cleaned data but these are still outliers

# %%
Sale['price']
# Out:
# 6438    175000.00
# 6439    386865.00
# 6440    330435.00
# 6441    288160.00
# 6442    288160.00
#            ...
# 28205   245000.00
# 28209   479000.00
# 28212   360000.00
# 28214   325000.00
# 28218   529000.00
# Name: price, Length: 20055, dtype: float64

# %%
# Box Plot For SALE PRİCES 
import matplotlib.pyplot as plt
sns.boxplot(data=Sale, x= 'price');

# %%
import matplotlib.pyplot as plt

plt.scatter(merged_df['price'],merged_df['area_of_the_garden'], color='r')
plt.show()

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 27945 entries, 0 to 28218
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   to_rent                 27945 non-null  bool
#  1   price                   27945 non-null  float64
#  2   number_of_rooms         27945 non-null  float64
#  3   living_area             27945 non-null  float64
#  4   fully_equipped_kitchen  27945 non-null  bool
#  5   furnished               27945 non-null  bool
#  6   open_fire               27945 non-null  bool
#  7   terrace                 27945 non-null  bool
#  8   area_of_the_terrace     27945 non-null  float64
#  9   garden                  27945 non-null  bool
#  10  area_of_the_garden      27945 non-null  float64
#  11  swimming_pool           27945 non-null  bool
#  12  state_of_the_building   27945 non-null  object
#  13  zipcode                 27945 non-null  int64
# ...

# %% [markdown]
# ### <p style="background-color:blue; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:15px 10px;">Represent the number of properties according to their surface using a histograms</p>

# %%
import matplotlib.pyplot as plt

plt.hist(df["living_area"], bins=25, edgecolor="black")
plt.xlabel('Living Area')
# Out:
# Text(0.5, 0, 'Living Area')

# %% [markdown]
# ### <p style="background-color:blue; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:15px 10px;">What are the <strong>most</strong> expensive municipalities in Belgium? (Average price, median price, price per square meter)</p>

# %%
merged_df
# Out:
#        to_rent     price  number_of_rooms  living_area  \
# 0         True    485.00             1.00        40.00
# 1         True    790.00             2.00       140.00
# 2         True    520.00             2.00        50.00
# 3         True    640.00             1.00       160.51
# 4         True    660.00             2.00        95.00
# ...        ...       ...              ...          ...
# 28205    False 245000.00             5.00       180.00
# 28209    False 479000.00             5.00       150.00
# 28212    False 360000.00             4.00       180.00
# 28214    False 325000.00             2.00       109.00
# 28218    False 529000.00             2.00       134.00
#
#        fully_equipped_kitchen  furnished  open_fire  terrace  \
# 0                        True      False      False    False
# 1                        True      False      False    False
# 2                        True      False      False    False
# ...

# %%
Sale.groupby('region_be')['price'].describe()
# Out:
#                     count      mean       std      min       25%       50%  \
# region_be
# Brussels          1161.00 399576.45 175393.96 95000.00 260000.00 360000.00
# Region Flanders   8520.00 327220.52 125664.89 49000.00 240000.00 299925.00
# Region Walloonie 10374.00 270463.94 142341.68 44000.00 175000.00 245000.00
#
#                        75%       max
# region_be
# Brussels         499000.00 999000.00
# Region Flanders  385000.00 999000.00
# Region Walloonie 325000.00 999000.00

# %%
Rent.groupby('region_be')['price'].describe()
# Out:
#                    count    mean    std    min     25%     50%     75%     max
# region_be
# Brussels         1465.00 1645.44 753.00 500.00 1150.00 1450.00 1900.00 7000.00
# Region Flanders  3031.00  989.15 363.52 390.00  780.00  895.00 1100.00 6000.00
# Region Walloonie 3394.00  833.59 342.62 250.00  650.00  760.00  900.00 7000.00

# %%
Rent.groupby('zipcode')['price_perm2'].mean().sort_values(ascending= False)
# Out:
# zipcode
# 1050   17.44
# 1000   17.29
# 1210   16.87
# 1040   16.80
# 8300   16.73
#         ...
# 2370    4.05
# 5520    3.74
# 5360    3.74
# 5352    3.00
# 5031    2.99
# Name: price_perm2, Length: 759, dtype: float64

# %% [markdown]
# <p>as you can see the most expensive town is IXELLES, BRUSSEL </p>
# <img src="https://i.hizliresim.com/rtbtatx.png" alt="Resim Aç">

# %%
Sale.groupby('zipcode')['price_perm2'].mean().sort_values(ascending= False)
# Out:
# zipcode
# 4506   9727.27
# 8300   7897.67
# 1933   6260.20
# 7191   5909.09
# 8301   4928.20
#          ...
# 7803    800.00
# 6951    691.06
# 5646    657.14
# 7608    541.99
# 7322    529.58
# Name: price_perm2, Length: 951, dtype: float64

# %%
Sale[Sale["zipcode"] == 4506]
# Out:
#        to_rent     price  number_of_rooms  living_area  \
# 22136    False 749000.00             2.00        77.00
#
#        fully_equipped_kitchen  furnished  open_fire  terrace  \
# 22136                    True      False      False    False
#
#        area_of_the_terrace  garden  area_of_the_garden  swimming_pool  \
# 22136                 0.00   False                0.00          False
#
#       state_of_the_building  zipcode         type         region_be  \
# 22136         excellentétat     4506  Appartement  Region Walloonie
#
#        price_perm2
# 22136      9727.27

# %%
Sale.drop(22136, inplace=True)

# %%
Sale.groupby('zipcode')['price_perm2'].mean().sort_values(ascending= False)
# Out:
# zipcode
# 8300   7897.67
# 1933   6260.20
# 7191   5909.09
# 8301   4928.20
# 3000   4846.94
#          ...
# 7803    800.00
# 6951    691.06
# 5646    657.14
# 7608    541.99
# 7322    529.58
# Name: price_perm2, Length: 950, dtype: float64

# %% [markdown]
# <p>as you can see for the price of the house the most expensive town is Knokke-Heist </p>
# <img src="https://i.hizliresim.com/g6wsqrq.png" alt="Resim Aç">

# %% [markdown]
# ### <p style="background-color:blue; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:15px 10px;">What are the <strong>most</strong> expensive municipalities in Wallonie? (Average price, median price, price per square meter)</p>

# %%
Wallon = merged_df[merged_df['region_be'] == 'Region Walloonie']
Wallon_Sale = Sale[Sale['region_be'] == 'Region Walloonie']
Wallon_Rent = Rent[Rent['region_be'] == 'Region Walloonie']

# %%
Wallon_Sale['zipcode'].value_counts()[8300] # I made this beacuse some zipcodes are 8300 but they are saved as Region wallonie by users
# Out:
# 190

# %%
Wallon = Wallon [Wallon.zipcode != 8300]
Wallon_Sale = Wallon_Sale[Wallon_Sale.zipcode != 8300]
Wallon_Rent = Wallon_Rent[Wallon_Rent.zipcode != 8300]

# %%
Wallon.price.describe()
# Out:
# count    13498.00
# mean    198576.05
# std     159654.41
# min        250.00
# 25%      65000.00
# 50%     195000.00
# 75%     290000.00
# max     999000.00
# Name: price, dtype: float64

# %%
Wallon_Sale.price.describe()
# Out:
# count    10183.00
# mean    262883.87
# std     129972.10
# min      44000.00
# 25%     175000.00
# 50%     240000.00
# 75%     320000.00
# max     999000.00
# Name: price, dtype: float64

# %%
Wallon_Rent.price.describe()
# Out:
# count   3314.00
# mean     809.95
# std      266.99
# min      250.00
# 25%      650.00
# 50%      750.00
# 75%      895.00
# max     3750.00
# Name: price, dtype: float64

# %% [markdown]
# #### Region Wallonie sorting prices for general

# %%
Wallon.groupby('zipcode')['price_perm2'].mean().sort_values(ascending= False)
# Out:
# zipcode
# 4506   9727.27
# 7191   5909.09
# 1341   4474.34
# 8301   3913.30
# 8670   3726.34
#          ...
# 4852      5.00
# 7940      4.96
# 7320      4.21
# 5360      3.74
# 5352      3.00
# Name: price_perm2, Length: 598, dtype: float64

# %% [markdown]
# #### Region Wallonie sorting prices for Rent

# %%
Wallon_Rent.groupby('zipcode')['price_perm2'].mean().sort_values(ascending= False)
# Out:
# zipcode
# 6747   13.60
# 1410   13.48
# 8660   13.04
# 5022   12.73
# 1440   12.45
#         ...
# 6540    4.21
# 5520    3.74
# 5360    3.74
# 5352    3.00
# 5031    2.99
# Name: price_perm2, Length: 424, dtype: float64

# %%
Wallon_Rent.groupby('zipcode')['price_perm2'].mean().sort_values(ascending= True)
# Out:
# zipcode
# 5031    2.99
# 5352    3.00
# 5360    3.74
# 5520    3.74
# 6540    4.21
#         ...
# 1440   12.45
# 5022   12.73
# 8660   13.04
# 1410   13.48
# 6747   13.60
# Name: price_perm2, Length: 424, dtype: float64

# %% [markdown]
# <p>as you can see for the rent prices of the houses the most expensive town in Wallonia is 6747 Saint-Léger  </p>
# <img src="https://i.hizliresim.com/39vus4o.png" alt="Resim Aç">

# %% [markdown]
# #### Region Wallonie sorting prices for Sale

# %%
Wallon_Sale.groupby('zipcode')['price_perm2'].mean().sort_values(ascending= False)
# Out:
# zipcode
# 7191   5909.09
# 8301   4928.20
# 8620   4543.71
# 1341   4474.34
# 8670   4280.65
#          ...
# 7803    800.00
# 6951    691.06
# 5646    657.14
# 7608    541.99
# 7322    529.58
# Name: price_perm2, Length: 569, dtype: float64

# %%
Wallon_Sale.groupby('zipcode')['price_perm2'].mean().sort_values(ascending= True)
# Out:
# zipcode
# 7322    529.58
# 7608    541.99
# 5646    657.14
# 6951    691.06
# 7803    800.00
#          ...
# 8670   4280.65
# 1341   4474.34
# 8620   4543.71
# 8301   4928.20
# 7191   5909.09
# Name: price_perm2, Length: 569, dtype: float64

# %% [markdown]
# <p>as you can see for the price of the house the most expensive town in Wallonia is 7191 Ecaussinnes  </p>
# <img src="https://i.hizliresim.com/byu25mi.png" alt="Resim Aç">

# %% [markdown]
# ###  <p style="background-color:blue; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:15px 10px;">What are the <strong>most</strong> expensive municipalities in Flanders? (Average price, median price, price per square meter)</p>

# %%
Flaman = merged_df[merged_df['region_be'] == 'Region Flanders']
Flaman_Sale = Sale[Sale['region_be'] == 'Region Flanders']
Flaman_Rent = Rent[Rent['region_be'] == 'Region Flanders']

# %%
Flaman.price.describe()
# Out:
# count    11551.00
# mean    241616.91
# std     179577.21
# min        390.00
# 25%       1650.00
# 50%     259100.00
# 75%     350000.00
# max     999000.00
# Name: price, dtype: float64

# %%
Flaman_Rent.price.describe()
# Out:
# count   3031.00
# mean     989.15
# std      363.52
# min      390.00
# 25%      780.00
# 50%      895.00
# 75%     1100.00
# max     6000.00
# Name: price, dtype: float64

# %%
Flaman_Sale.price.describe()
# Out:
# count     8520.00
# mean    327220.52
# std     125664.89
# min      49000.00
# 25%     240000.00
# 50%     299925.00
# 75%     385000.00
# max     999000.00
# Name: price, dtype: float64

# %%
Flaman_Sale.groupby('zipcode')['price_perm2'].mean().sort_values(ascending= False)
# Out:
# zipcode
# 1933   6260.20
# 3000   4846.94
# 1950   4308.36
# 9051   4069.74
# 9052   3965.47
#          ...
# 3770   1633.54
# 3454   1472.60
# 3404   1323.40
# 2491   1177.53
# 3621   1152.08
# Name: price_perm2, Length: 357, dtype: float64

# %%
Flaman_Sale.groupby('zipcode')['price_perm2'].mean().sort_values(ascending= True)
# Out:
# zipcode
# 3621   1152.08
# 2491   1177.53
# 3404   1323.40
# 3454   1472.60
# 3770   1633.54
#          ...
# 9052   3965.47
# 9051   4069.74
# 1950   4308.36
# 3000   4846.94
# 1933   6260.20
# Name: price_perm2, Length: 357, dtype: float64

# %%
Flaman_Rent.groupby('zipcode')['price_perm2'].mean().sort_values(ascending= False)
# Out:
# zipcode
# 1950   15.30
# 2320   14.41
# 3790   13.98
# 2000   13.93
# 1750   13.29
#         ...
# 2491    4.83
# 9680    4.80
# 9910    4.70
# 2243    4.39
# 2370    4.05
# Name: price_perm2, Length: 312, dtype: float64

# %%
Flaman_Rent.groupby('zipcode')['price_perm2'].mean().sort_values(ascending= True)
# Out:
# zipcode
# 2370    4.05
# 2243    4.39
# 9910    4.70
# 9680    4.80
# 2491    4.83
#         ...
# 1750   13.29
# 2000   13.93
# 3790   13.98
# 2320   14.41
# 1950   15.30
# Name: price_perm2, Length: 312, dtype: float64

# %% [markdown]
# <p>as you can see for the price of the house the most expensive town in Flanders is Kraainem  </p>
# <img src="https://i.hizliresim.com/j0e2mn5.png" alt="Resim Aç">

# %% [markdown]
# ## <p style="background-color:#9B59B6; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Step 7 : Data Visualization</p>

# %%
df = merged_df

# %%
df
# Out:
#        to_rent     price  number_of_rooms  living_area  \
# 0         True    485.00             1.00        40.00
# 1         True    790.00             2.00       140.00
# 2         True    520.00             2.00        50.00
# 3         True    640.00             1.00       160.51
# 4         True    660.00             2.00        95.00
# ...        ...       ...              ...          ...
# 28205    False 245000.00             5.00       180.00
# 28209    False 479000.00             5.00       150.00
# 28212    False 360000.00             4.00       180.00
# 28214    False 325000.00             2.00       109.00
# 28218    False 529000.00             2.00       134.00
#
#        fully_equipped_kitchen  furnished  open_fire  terrace  \
# 0                        True      False      False    False
# 1                        True      False      False    False
# 2                        True      False      False    False
# ...

# %% [markdown]
# #### General

# %%
Rent['region_be'].value_counts().plot(kind='bar')
plt.xlabel('Bölge')
plt.ylabel('Ev Sayısı')
plt.title('Kiralık evlerin bölgelerine göre dağılımı')
# Out:
# Text(0.5, 1.0, 'Kiralık evlerin bölgelerine göre dağılımı')

# %%
import matplotlib.cm as cm

# Calculate the average price per square meter by region
avg_price_perm2 = Rent.groupby('region_be')['price_perm2'].mean()

# Create the bar chart
colors = cm.viridis(np.linspace(0, 1, len(avg_price_perm2)))
avg_price_perm2.plot(kind='bar', color=colors)
plt.xlabel('Region')
plt.ylabel('Avarage Price/m²')
plt.title('Comparison of price rates of rental houses by region')
plt.show()

# %%
# Sum the number of properties with each feature
feature_counts = Rent[['fully_equipped_kitchen', 'furnished', 'open_fire', 'terrace', 'garden', 'swimming_pool']].sum()

# Create the pie chart
colors = cm.viridis_r(np.linspace(0, 1, len(feature_counts)))
feature_counts.plot.pie(autopct='%1.1f%%', colors=colors)
plt.title('Percentage distribution of rental houses and equipment')
plt.show()

# %%
df_type_price = Rent[['type', 'price']]
df_type_price = df_type_price.groupby('type').mean().sort_values(by= 'price', ascending= False)
# Bar grafiği oluşturun
df_type_price[:5].plot(kind='barh', y='price', legend=False)

# Grafiğin başlığını ekleyin
plt.title('Ortalama Kira Fiyatı Farklı Türlerdeki Evler İçin')

# Y ekseninin etiketini ekleyin
plt.ylabel('Ortalama Metrekare Fiyatı (EUR)')


# Grafiği gösterin
plt.show()

# %%
# Find the top 5 most common values in the 'type' column
top_5_types = Rent['type'].value_counts().nlargest(6).index.tolist()

#Filter dataframe to keep only the rows with the top 5 types
Rent2 = Rent[Rent['type'].isin(top_5_types)]

#violin plot 
plt.title('6 Most Rental Logement Types and Price information')
sns.violinplot(x='type', y='price', data=Rent2)
plt.show()

# %% [markdown]
# #### Wallon

# %%
Wallon
# Out:
#        to_rent     price  number_of_rooms  living_area  \
# 0         True    485.00             1.00        40.00
# 2         True    520.00             2.00        50.00
# 4         True    660.00             2.00        95.00
# 6         True    900.00             3.00       170.00
# 12        True    860.00             2.00        95.00
# ...        ...       ...              ...          ...
# 28187    False 450000.00             2.00        72.00
# 28190    False 349000.00             2.00       110.00
# 28200    False 245000.00             5.00       180.00
# 28203    False 185000.00             3.00       120.00
# 28205    False 245000.00             5.00       180.00
#
#        fully_equipped_kitchen  furnished  open_fire  terrace  \
# 0                        True      False      False    False
# 2                        True      False      False    False
# 4                        True      False      False    False
# ...

# %%
Wallon_Sale
# Out:
#        to_rent     price  number_of_rooms  living_area  \
# 6457     False  99000.00             1.00        62.00
# 6458     False 197500.00             2.00        81.00
# 6459     False 210000.00             2.00        80.00
# 6462     False 250000.00             5.00       200.00
# 6463     False 209000.00             4.00       180.00
# ...        ...       ...              ...          ...
# 28187    False 450000.00             2.00        72.00
# 28190    False 349000.00             2.00       110.00
# 28200    False 245000.00             5.00       180.00
# 28203    False 185000.00             3.00       120.00
# 28205    False 245000.00             5.00       180.00
#
#        fully_equipped_kitchen  furnished  open_fire  terrace  \
# 6457                    False      False      False     True
# 6458                     True      False      False    False
# 6459                     True      False      False     True
# ...

# %%
Wallon_Rent
# Out:
#        to_rent  price  number_of_rooms  living_area  fully_equipped_kitchen  \
# 0         True 485.00             1.00        40.00                    True
# 2         True 520.00             2.00        50.00                    True
# 4         True 660.00             2.00        95.00                    True
# 6         True 900.00             3.00       170.00                    True
# 12        True 860.00             2.00        95.00                    True
# ...        ...    ...              ...          ...                     ...
# 28202     True 850.00             2.00       102.00                    True
# 28204     True 640.00             1.00        80.00                    True
# 28210     True 945.00             3.00       160.51                    True
# 28215     True 920.00             3.00       163.00                    True
# 28217     True 930.00             3.00       155.00                    True
#
# ...

# %%
# Kiralık ve satılık gayrimenkuller arasındaki fiyat farkını gösteren box plot çizin
Wallon.boxplot(column=['living_area'], by=['to_rent'])
plt.ylabel('Price')
plt.show()

# %%
# Find the top 5 most common values in the 'type' column
top_5_types = Wallon_Rent['type'].value_counts().nlargest(6).index.tolist()

#Filter dataframe to keep only the rows with the top 5 types
Wallon_Rent_2 = Wallon_Rent[Wallon_Rent['type'].isin(top_5_types)]

# %%
sns.violinplot(x='type', y='price', data=Wallon_Rent_2)
plt.show()

# %%
#Calculating the mean prices 
mean_price = Wallon_Rent['price'].mean()
print("Avarage Rent Price İn wallonie : ",mean_price)

#Calculating the max and min  prices 
max_price_Wallon_Rent = Wallon_Rent['price'].max()
min_price_Wallon_Rent = Wallon_Rent['price'].min()
print("Max Price is : ",max_price_Wallon_Rent," Min Price is : ",min_price_Wallon_Rent)

#Visualize the distribution of the number of rooms
plt.hist(Wallon_Rent['number_of_rooms'], bins=range(1,9))
plt.xlabel('Number of Rooms')
plt.ylabel('Frequency')
plt.show()
# Out:
# Avarage Rent Price İn wallonie :  809.9456849728425
# Max Price is :  3750.0  Min Price is :  250.0

# %%
Rent = merged_df[merged_df['to_rent'] == True]
Sale = merged_df[merged_df['to_rent'] == False]

# %%
# Calculate the average price per square meter by region
avg_price_perm2 = Sale.groupby('region_be')['price_perm2'].mean()

# Create the line chart
plt.plot(avg_price_perm2.index, avg_price_perm2.values)
plt.xlabel('Region')
plt.ylabel('Average Price per Square Meter')
plt.show()

# %%
# Group the data by the 'region_be' column
grouped_data = df.groupby('region_be')

# Calculate the average number of rooms, living area, and price per square meter for each group
avg_rooms = grouped_data['number_of_rooms'].mean()
avg_area = grouped_data['living_area'].mean()
avg_price_perm2 = grouped_data['price_perm2'].mean()

# Calculate the proportion of properties with a garden or terrace for each group
proportion_garden = grouped_data['garden'].sum() / grouped_data.size()
proportion_terrace = grouped_data['terrace'].sum() / grouped_data.size()
